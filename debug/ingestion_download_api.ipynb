# %%
# %pip install --force-reinstall /Volumes/dev/tools/whl/solvx_databricks_utils-0.1.0-py3-none-any.whl

# %%
# %restart_python

# %%
import requests
from dbx_utils.ingest.download_api import download_endpoint_to_volume
from dbx_utils.logging import getLogger

logger = getLogger(__name__)


# Build session, incl. certs + headers
session = requests.Session()
session.headers.update({
    "Authorization": "Bearer YOUR_ACCESS_TOKEN_HERE",
    "Accept": "application/json",
})


# attach cert
# session.verify = "/tmp/my_cert.pem"

# add authentication & headers
# session.headers.update({
#     "Authorization": dbutils.secrets.get("keyvault", "api-basic"),
#     "Accept": "application/json",
# })


endpoint = "https://pokeapi.co/api/v2/pokemon?limit=20&offset=0"
params = {
    "limit": "20",
    "offset": "0"
}
options = {
    "pagination_key": "next"
}

download_folder = (
    f"/Volumes/dev/tools/testing/test/"
)

logger.info("Downloading endpoint=%s", endpoint)

total = download_endpoint_to_volume(
    session=session,
    endpoint=endpoint,
    params=params,
    options=options,
    download_folder=download_folder,
    # dbutils=dbutils,
)

logger.info("Downloaded %s pages → %s", total, download_folder)
