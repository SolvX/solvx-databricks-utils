# %%
# %pip install --force-reinstall /Volumes/dev/tools/whl/solvx_databricks_utils-0.1.0-py3-none-any.whl

# %%
# %restart_python

# %%
from dbx_utils.ingest import import_json

dbutils.widgets.text("Volume location", "")

# %%
volume = dbutils.widgets.get("Volume location")

import_json(volume_path=volume)

# %%
# %sql
SELECT * FROM dev.tools.test
