# %%
dbutils.widgets.text("path", "/Workspace/Users/[EMAIL]/solvx-databricks-utils")
path = dbutils.widgets.get("path")

# %%
cmd = f"%pip install -e {path}"
print(cmd)

# %%
# %pip uninstall -y solvx-databricks-utils

# %%
# %pip install -e $path

# %%
# %restart_python

# %%
# %pip show solvx-databricks-utils

# %%
import sys
print(sys.version)
print("\n--- sys.path ---")
for p in sys.path:
    print(p)

import dbx_utils
print("\nDBX_UTILS MODULE FILE:", dbx_utils.__file__)

# %%
# %pip show -f solvx-databricks-utils
