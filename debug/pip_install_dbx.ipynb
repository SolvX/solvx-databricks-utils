# %%
# The dist wheel should be located in /Volumes/dev/tools/whl/solvx_databricks_utils.whl
# Otherwise change path accordingly


# %pip install /Volumes/dev/tools/whl/solvx_databricks_utils-0.1.0-py3-none-any.whl

# %%
# quick test

from dbx_utils.logging import DEFAULT_LOG_FORMAT, getLogger

logger = getLogger()
logger.info("This works")
