# %%
# install the logger with
# python -m build --wheel
# pip install --force-reinstall dist/solvx_databricks_utils-0.1.0-py3-none-any.whl

# or on windows: .\scripts\update-wheel.ps1

# %%
from logging import NullHandler

from dbx_utils.logging import DEFAULT_LOG_FORMAT, getLogger

# %%
logger = getLogger()

# %%
logger.info("test")
# Out:
# 2025-11-27 10:28:28 - dbx_utils.logging - INFO - test

# %%
logger.setLevel("WARNING")
logger.info("test1")
logger.warning("test1")
# Out:
# 2025-11-27 10:30:02 - dbx_utils.logging - WARNING - test1
